# %% [markdown]
# ## 프로그래머스 단어 변환
#
# *두 개의 단어 begin, target과 단어의 집합 words가 있습니다. 아래와 같은 규칙을 이용하여 begin에서 target으로 변환하는 가장 짧은 변환 과정을 찾으려고 합니다.*
#
# 1. 한 번에 한 개의 알파벳만 바꿀 수 있습니다.
# 2. words에 있는 단어로만 변환할 수 있습니다.
#
# *예를 들어 begin이 hit, target가 cog, words가 [hot,dot,dog,lot,log,cog]라면 hit -> hot -> dot -> dog -> cog와 같이 4단계를 거쳐 변환할 수 있습니다.*
#
# *두 개의 단어 begin, target과 단어의 집합 words가 매개변수로 주어질 때, 최소 몇 단계의 과정을 거쳐 begin을 target으로 변환할 수 있는지 return 하도록 solution 함수를 작성해주세요.*
#
# **제한사항**
#
# - 각 단어는 알파벳 소문자로만 이루어져 있습니다.
# - 각 단어의 길이는 3 이상 10 이하이며 모든 단어의 길이는 같습니다.
# - words에는 3개 이상 50개 이하의 단어가 있으며 중복되는 단어는 없습니다.
# - begin과 target은 같지 않습니다.
# - 변환할 수 없는 경우에는 0를 return 합니다.

# %%
answer = 0
def solution(begin, target, words):
    #depth=0으로 시작함.
    dfs(begin, target, 0, words)
    return answer

def change(src, dst):
    for i in range(len(src)):
        if src[:i]+src[i+1:] == dst[:i] + dst[i+1:]:
            print("change?: ", src[:i]+src[i+1:],dst[:i] + dst[i+1:])
            return True
    print("실패입니당!.")
    return False

def dfs(begin, target, d, words):
    global answer
    print("begin1: ", begin)
    print("words list: ", words)
    if begin == target:
        print("depth? : ",d)
        answer = d
        return
    else:
        if len(words) == 0:
            return 
        for w in range(len(words)):
            if change(begin, words[w]):
                word = words[:w]+words[w+1:]
                print("다음차원으로 갈 word :", word)
                print("다음차원에 안가는 word : ", words[w])
                dfs(words[w], target, d+1, word)

# %%
solution("hit","cog",["hot", "dot", "dog", "lot", "log", "cog"])
# Out:
# begin1:  hit
# words list:  ['hot', 'dot', 'dog', 'lot', 'log', 'cog']
# change?:  ht ht
# 다음차원으로 갈 word : ['dot', 'dog', 'lot', 'log', 'cog']
# 다음차원에 안가는 word :  hot
# begin1:  hot
# words list:  ['dot', 'dog', 'lot', 'log', 'cog']
# change?:  ot ot
# 다음차원으로 갈 word : ['dog', 'lot', 'log', 'cog']
# 다음차원에 안가는 word :  dot
# begin1:  dot
# words list:  ['dog', 'lot', 'log', 'cog']
# change?:  do do
# 다음차원으로 갈 word : ['lot', 'log', 'cog']
# 다음차원에 안가는 word :  dog
# begin1:  dog
# words list:  ['lot', 'log', 'cog']
# 실패입니당!.
# change?:  og og
# 다음차원으로 갈 word : ['lot', 'cog']
# 다음차원에 안가는 word :  log
# begin1:  log
# words list:  ['lot', 'cog']
# change?:  lo lo
# 다음차원으로 갈 word : ['cog']
# 다음차원에 안가는 word :  lot
# begin1:  lot
# words list:  ['cog']
# 실패입니당!.
# change?:  og og
# 다음차원으로 갈 word : ['lot']
# 다음차원에 안가는 word :  cog
# begin1:  cog
# words list:  ['lot']
# depth? :  5
# change?:  og og
# 다음차원으로 갈 word : ['lot', 'log']
# 다음차원에 안가는 word :  cog
# begin1:  cog
# words list:  ['lot', 'log']
# depth? :  4
# change?:  ot ot
# 다음차원으로 갈 word : ['dog', 'log', 'cog']
# 다음차원에 안가는 word :  lot
# begin1:  lot
# words list:  ['dog', 'log', 'cog']
# 실패입니당!.
# change?:  lo lo
# 다음차원으로 갈 word : ['dog', 'cog']
# 다음차원에 안가는 word :  log
# begin1:  log
# words list:  ['dog', 'cog']
# change?:  og og
# 다음차원으로 갈 word : ['cog']
# 다음차원에 안가는 word :  dog
# begin1:  dog
# words list:  ['cog']
# change?:  og og
# 다음차원으로 갈 word : []
# 다음차원에 안가는 word :  cog
# begin1:  cog
# words list:  []
# depth? :  6
# change?:  og og
# 다음차원으로 갈 word : ['dog']
# 다음차원에 안가는 word :  cog
# begin1:  cog
# words list:  ['dog']
# depth? :  5
# 실패입니당!.
# 실패입니당!.
# 실패입니당!.
# 실패입니당!.
# change?:  ot ot
# 다음차원으로 갈 word : ['dot', 'dog', 'log', 'cog']
# 다음차원에 안가는 word :  lot
# begin1:  lot
# words list:  ['dot', 'dog', 'log', 'cog']
# change?:  ot ot
# 다음차원으로 갈 word : ['dog', 'log', 'cog']
# 다음차원에 안가는 word :  dot
# begin1:  dot
# words list:  ['dog', 'log', 'cog']
# change?:  do do
# 다음차원으로 갈 word : ['log', 'cog']
# 다음차원에 안가는 word :  dog
# begin1:  dog
# words list:  ['log', 'cog']
# change?:  og og
# 다음차원으로 갈 word : ['cog']
# 다음차원에 안가는 word :  log
# begin1:  log
# words list:  ['cog']
# change?:  og og
# 다음차원으로 갈 word : []
# 다음차원에 안가는 word :  cog
# begin1:  cog
# words list:  []
# depth? :  6
# change?:  og og
# 다음차원으로 갈 word : ['log']
# 다음차원에 안가는 word :  cog
# begin1:  cog
# words list:  ['log']
# depth? :  5
# 실패입니당!.
# 실패입니당!.
# 실패입니당!.
# change?:  lo lo
# 다음차원으로 갈 word : ['dot', 'dog', 'cog']
# 다음차원에 안가는 word :  log
# begin1:  log
# words list:  ['dot', 'dog', 'cog']
# 실패입니당!.
# change?:  og og
# 다음차원으로 갈 word : ['dot', 'cog']
# 다음차원에 안가는 word :  dog
# begin1:  dog
# words list:  ['dot', 'cog']
# change?:  do do
# 다음차원으로 갈 word : ['cog']
# 다음차원에 안가는 word :  dot
# begin1:  dot
# words list:  ['cog']
# 실패입니당!.
# change?:  og og
# 다음차원으로 갈 word : ['dot']
# 다음차원에 안가는 word :  cog
# begin1:  cog
# words list:  ['dot']
# depth? :  5
# change?:  og og
# 다음차원으로 갈 word : ['dot', 'dog']
# 다음차원에 안가는 word :  cog
# begin1:  cog
# words list:  ['dot', 'dog']
# depth? :  4
# 실패입니당!.
# 실패입니당!.
# 실패입니당!.
# 실패입니당!.
# 실패입니당!.
# 실패입니당!.
# 실패입니당!.
# 실패입니당!.
# 4
